# %% [markdown]
# <a href="https://colab.research.google.com/github/qunyizhao/DKU_Econ204/blob/main/Qunyi_Zhao_Econ204_Rational_Expectation_Theory_Inflation_and_Interest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: The Monetary Market
#
# $M^d/P=m*Y/i$
#
# In equilibrum $M^s=M^d$
#
# Please Change one the exogenous variable for your homework

# %%
### Define exogenous variables
Ms= 1000
m=1
Y=10
i=0.05

# %%
### Calculate the equilibrium P level
P=Ms*i/(m*Y)
print(P)
# Out:
# 5.0

# %%
### draw the equilibrium
import matplotlib.pyplot as plt
import numpy as np
fig= plt.figure(figsize=(20,10))
x = np.linspace(0, 2000)
y = i/(m*Y)*x
###draw an vertical line for monetary supply
plt.axvline(x=Ms, Label='Ms')
plt.plot(x,y, Label='Md=L(Y,i)')

###plot label, legend, and title
plt.xlabel('M')
plt.ylabel('P')
plt.legend()
plt.title('The Monetary Market Equlibrium')
plt.show()

# %% [markdown]
# # Task 2: The Comparative Statics for the Monetary Market

# %% [markdown]
# ## Task 2.1 The Change in Ms
#
# Please change Ms2 for your homework

# %%
### Define exogenous variables
Ms1= 1000
Ms2= 2000
m=1
Y=10
i=0.05

# %%
### Calculate the equilibrium P level
P1=Ms1*i/(m*Y)
P2=Ms2*i/(m*Y)
print(P1, P2)
# Out:
# 5.0 10.0

# %%
### draw the equilibrium
import matplotlib.pyplot as plt
import numpy as np
fig= plt.figure(figsize=(20,10))
x = np.linspace(0, 2000)
y = i/(m*Y)*x
###draw an vertical line for monetary supply
plt.axvline(x=Ms1, Label='Ms1')
plt.axhline(y=P1,linestyle='--',color='r')
plt.axvline(x=Ms2, Label='Ms2')
plt.axhline(y=P2,linestyle='--',color='r')
plt.plot(x,y, Label='Md=L(Y,i)')

###plot label, legend, and title
plt.xlabel('M')
plt.ylabel('P')
plt.legend()
plt.title('The Monetary Market Equlibrium')
plt.show()

# %% [markdown]
# ## Task 2.2 The Change in m
#
# Please change m2 for your homework

# %%
### Define exogenous variables
Ms= 1000
m1=1
m2=0.5
Y=10
i=0.05

# %%
### Calculate the equilibrium P level
P1=Ms*i/(m1*Y)
P2=Ms*i/(m2*Y)
print(P1,P2)
# Out:
# 5.0 10.0

# %%
### draw the equilibrium
import matplotlib.pyplot as plt
import numpy as np
fig= plt.figure(figsize=(20,10))
x = np.linspace(0, 2000)
y1 = i/(m1*Y)*x
y2 = i/(m2*Y)*x
###draw an vertical line for monetary supply
plt.axhline(y=P1,linestyle='--',color='r')
plt.axvline(x=Ms, Label='Ms')
plt.axhline(y=P2,linestyle='--',color='green')
plt.plot(x,y1, Label='Md=L(Y,i), m=m1')
plt.plot(x,y2, Label='Md=L(Y,i), m=m2',color='green')


###plot label, legend, and title
plt.xlabel('M')
plt.ylabel('P')
plt.legend()
plt.title('The Monetary Market Equlibrium')
plt.show()

# %% [markdown]
# ## Task 2.3 The Change in Y
#
# Please change Y2 for your homework

# %%
### Define exogenous variables
Ms= 1000
m=1
Y1=10
Y2=25
i=0.05

# %%
### Calculate the equilibrium P level
P1=Ms*i/(m*Y1)
P2=Ms*i/(m*Y2)
print(P1, P2)
# Out:
# 5.0 2.0

# %%
### draw the equilibrium
import matplotlib.pyplot as plt
import numpy as np
fig= plt.figure(figsize=(20,10))
x = np.linspace(0, 2000)
y1 = i/(m*Y1)*x
y2 = i/(m*Y2)*x
###draw an vertical line for monetary supply
plt.axhline(y=P1,linestyle='--',color='B')
plt.axvline(x=Ms, Label='Ms')
plt.axhline(y=P2,linestyle='--',color='green')
plt.plot(x,y1, Label='Md=L(Y,i), Y=Y1',color='B')
plt.plot(x,y2, Label='Md=L(Y,i), Y=Y2',color='green')


###plot label, legend, and title
plt.xlabel('M')
plt.ylabel('P')
plt.legend()
plt.title('The Monetary Market Equlibrium')
plt.show()

# %% [markdown]
# ## Task 2.4 Price Targeting and Endegenous Monetary Supply
# Please change P for your homework

# %%
### Define exogenous variables
P1=7
m=1
Y1=10
Y2=20
i=0.05

# %%
### Calculate the Endegenous Monetary Supply
Ms1=P1*(m*Y1)/i
Ms2=P1*(m*Y2)/i
print(Ms1, Ms2)
# Out:
# 1400.0 2800.0

# %%
### draw the equilibrium
import matplotlib.pyplot as plt
import numpy as np
fig= plt.figure(figsize=(20,10))
x = np.linspace(0, 3000)
y1 = i/(m*Y1)*x
y2 = i/(m*Y2)*x
###draw an vertical line for monetary supply
plt.axhline(y=P1,linestyle='--',color='r')
plt.axvline(x=Ms1, Label='Ms1',color='B')
plt.axvline(x=Ms2, Label='Ms2',color='green')
plt.plot(x,y1, Label='Md=L(Y,i), Y=Y1',color='B')
plt.plot(x,y2, Label='Md=L(Y,i), Y=Y2',color='green')


###plot label, legend, and title
plt.xlabel('M')
plt.ylabel('P')
plt.legend()
plt.title('The Monetary Market Equlibrium')
plt.show()

# %% [markdown]
# # Task 3: Inflation and Real Interest Rate
# Please change Pie for your homework

# %%
### Define the exogneous variable
P1 = 5 # price level in the first period
Pie = 0.1 # the inflation rate
DA1=100 # nominal assets for the first period
i=0.03 # nominal interest rate

# %%
RA1=DA1/P1
DA2=DA1*(1+i)
P2=P1*(1+Pie)
RA2=DA2/P2
r=RA2/RA1-1
print(RA1,RA2,r, i-Pie)
# r: nominal interest rate; i-pie: real interest rate
# Out:
# 20.0 18.727272727272727 -0.06363636363636371 -0.07

# %% [markdown]
# #Task 4: Government Revenue by Printing More Money
# Please Change miu for your homework

# %%
### define the exogenous variable
Ms1=1000 # monetary supply for year1
Y=10 # GDP
m=1 # technology
i=0.05 # interest rate
miu =0.05 #the rate of money growth

# %%
Ms2=Ms1*(1+miu)
P2=Ms2*i/(m*Y)
Revenue = (Ms2-Ms1)/P2
Share_of_GDP=Revenue/Y
print(Revenue,Share_of_GDP)
# Out:
# 9.523809523809524 0.9523809523809523
